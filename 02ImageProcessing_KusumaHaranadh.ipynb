# %% [markdown]
# # AssignmentLecture2ConceptsIP_KusumaHaranadh

# %% [markdown]
# # EQUALIZE_HIST
# Syntax :
# equalize_hist(image, nbins=256, mask=None)
#
#
#
# Parameters :
#
#
#
# 1)image : array
#
#
#
# 2)nbins : int (This represents the Number of bins for image histogram and this argument is ignored for integer images, for which each integer is its own bin )
#
#
#
# 3)mask: array of bools or 0s and 1s (Array of same shape as `image`.Only points at which mask == True
#
# are used for the equalization, which is applied to the whole image)
#
#
#
# Explanation :
#
#
#
# equalize_hist function performs histogram equalization. It enhances the contrast of images by transforming the values in an intensity image so that the histogram of the output image approximately matches a specified histogram (uniform distribution by default).
# This Histogram Equalization is operated on the entire image.

# %% [markdown]
# # EQUALIZE_ADAPTHIST
#
#
#
# Syntax : skimage.exposure.equalize_adapthist(image, kernel_size=None, clip_limit=0.01, nbins=256)
#
#
#
# Parameters :
#
#
#
# 1)image : (M, N, [C]) ndarray
#
#
# 2)kernel_size: integer or list-like (It defines the shape of contextual regions used in the algorithm )
#
#
# 3)clip_limit : float (Clipping limit, normalized between 0 and 1 (higher values give more contrast))
#
#
# 4)nbins : int (Number of gray bins for histogram (“data range”))
#
#
#
# Explanation :
#
#
#
# equalize_adapthist performs contrast-limited adaptive histogram equalization. Unlike histeq, it operates on small data regions (tiles) rather than the entire image. Each tile's contrast is enhanced so that the histogram of each output region approximately matches the specified histogram (uniform distribution by default). The contrast enhancement can be limited in order to avoid amplifying the noise which might be present in the image.

# %% [markdown]
# # Histogram Equalization Vs Adaptive Histogram Equalization
#
#
# The Adaptive Histogram Equalization can be useful over Standard Histogram Equalization when there is a need for observing Smaller details in the image.
# In Anatomy, every detail counts and therefore Adaptive Histogram Equalization is preferred to Standard Histgram Equalization.

# %% [markdown]
# # 02 INVESTIGATION ASSIGNMENT

# %% [markdown]
# # IMAGE ENHANCEMENT TECHNIQUE
#
# The principle objective of Image Enhancement Techniques is to process an image so that the result is more suitable than the original image for a specific application.
#
#
# The main aim of image enhancementis to enhance thequality andvisual appearance of animage, or toprovide a better transform representation for future automated image processing.
#
#
# Many images like medical images, satellite, aerial images and also real life photographs suffer from poor and bad contrast and noise.
#
#
# It is necessary to enhance the contrast and remove the noise to increase image quality.
#
#
# One of the most important stages in medical images detection and analysis is Image Enhancement Techniques.
#
#
# It improves the clarity of images for human viewing, removing blurring and noise, increasing contrast, and revealing details.

# %% [markdown]
# # Filtering with morphological operators :
#
#
# Here is a step-by-step description of how this technique is carried out :
#
#
# Step 1: Read Image
#
# Step 2: Use Morphological Opening to Estimate the Background
#
# Step 3: Subtract the Background Image from the Original Image
#
# Step 4: Increase the Image Contrast
#
# Step 5: Threshold the Image
#
# Step 6: Identify Objects in the Image
#
# Step 7: Examine One Object
#
# Step 8: View All Objects
#
# Step 9: Compute Area of Each Object
#
# Step 10: Compute Area-based Statistics
#
# Step 11: Create Histogram of the Area

# %% [markdown]
# a)The technique is used for the Estimation of area or volume or different parameters of different objects present in an image.
# Example :
# Let us cosider an example in which there is an image consisting of 20 granules of rice.
# This technique can be used to estimate the area of each of the Rice granule seperately.
#
#
#
# b) The function "data = regionprops(cc,'basic')" can be used to determine the area or volume occupied by the Rice Grains individually.
# Syntax :
# data = regionprops(cc,'basic')
#
# Parameters :
#
#  1)cc = number or index of the component in the array whose area is to be determined.
#  2)basic = it is the type of parameter one would like to determine from the image.
#
#
#
# c)Yes.This Image Enhancement Technique can be useful in determining the areas of tumours,cancers,etc  present in the medical images
#
#
# d) 'Introduction to the Issue on Filtering and Segmentation With Mathematical Morphology' (http://ieeexplore.ieee.org/document/6329954/citations) by
#
#
# Authors :
#
#
# 1)Laurent Najman
# Laboratoired'Informatique Gaspard Monge, Université Paris-Est, 77454 Marne-la-Vallée, Cedex 2, France
#
#
# 2)Junior Barrera
# Computer Science Department Institute of Mathematics and Statistics, University of São Paulo, São Paulo 05508-090 SP, Brazil
#
#
# 3)B. S. Daya Sagar
# Systems Science and Informatics Unit, Indian Statistical Institute, Bangalore 560 059, India
#
#
# 4)Petros Maragos
# School of Electrical and Computer Engineering, National Technical University of Athens, Athens 15773, Greece
#
#
# 5)Dan Schonfeld
# Department of Electrical and Computer Engineering Department of Computer Science Department of Bioengineering, University of Illinois at Chicago, Chicago, IL, USA
